# %%
import pandas as pd

# %%
class fixtures():
    
    def __init__(self,filename):
        self.df = pd.DataFrame()
        self.load(filename)
        
    def load(self, filename):
        self.df = pd.read_csv(filename)
        self.df['FixtureDateAsDate']=pd.to_datetime(self.df['fixturedate'])
        self.df=self.df.sort_values(by='FixtureDateAsDate')
        
        return self
    
    def clean_fixtures(self):
        self.df.FTHG.fillna(0, inplace=True)
        self.df.FTAG.fillna(0, inplace=True)
        return self
    
    def add_features(self, nlist):
        grouped = self.df.groupby('HomeTeamID')

        for n in nlist:
            print ('***', n)
            rollmean_H = grouped['FTHG'].apply(pd.rolling_mean, n, min_periods=n)
            self.df['FTHG_roll_avg_'+str(n)]=(rollmean_H*(n+1) - self.df['FTHG'])/n

            grouped = self.df.groupby('AwayTeamID')
            rollmean_H = grouped['FTAG'].apply(pd.rolling_mean, n+1, min_periods=n+1)
            self.df['FTAG_roll_avg_'+str(n)]=(rollmean_H*(n+1) - self.df['FTAG'])/n

            self.df['FTHG_roll_avg_diff_'+str(n)]= self.df['FTHG_roll_avg_'+str(n)] - self.df['FTAG_roll_avg_'+str(n)]

        self.df['PointsDiff'] = self.df['HTPointsCum'] - self.df['ATPointsCum']
        
        return self

    def prep_classification(self, nlist, cleanna):

        cols=['HTPointsCum', 'ATPointsCum', 'PointsDiff']
        for colname in [ 'FTHG_roll_avg', 'FTAG_roll_avg', 'FTHG_roll_avg_diff']:
            cols.extend([colname+'_'+str(n) for n in nlist])
        if cleanna :
            self.df.dropna(axis=0,inplace=True)
        X=self.df[ cols ]
        y = self.df['ThisResult']


        return X, y
    
    def fixture_filter(self, start_date, end_date=None):
        if start_date:
            self.df=self.df[self.df.FixtureDateAsDate >= start_date]
        if end_date:
            self.df=self.df[self.df.FixtureDateAsDate <= end_date]
        
        return self

# %%
myfix=fixtures('test_football1.csv').fixture_filter(None,'2016-01-01')

# %%
myfix = myfix.clean_fixtures().add_features([3,4,5])
X,y=myfix.prep_classification([3,4,5],True)
# Out:
# *** 3
# *** 4
# *** 5

# %%
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
    clf =  RandomForestClassifier(max_depth=10, n_estimators=40, min_samples_leaf=10)

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)
    y_pred = clf.fit(X_train, y_train).predict(X_test)
    print(accuracy_score(y_test, y_pred))

    clf
# Out:
# 0.601699279094
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
pred_fix=fixtures('test_football1.csv')

# %%
pred_fix = pred_fix.clean_fixtures().add_features([3,4,5])
pred_fix = pred_fix.fixture_filter('2017-01-21','2017-01-21')
X_pred,y=pred_fix.prep_classification([3,4,5],False)
# Out:
# *** 3
# *** 4
# *** 5

# %%
pred_fix.df['Predicted']=clf.predict(X_pred)
pred_fix.df[['fixturedate', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'Predicted']].head()
# Out:
#     fixturedate            HomeTeam      AwayTeam  FTHG  FTAG Predicted
# 198  2017-01-21             Grimsby  Notts County     2     0         W
# 212  2017-01-21             Walsall   Bristol Rvs     3     1         L
# 211  2017-01-21            Man City     Tottenham     2     2         W
# 210  2017-01-21  Milton Keynes Dons   Northampton     5     3         L
# 209  2017-01-21             Norwich        Wolves     3     1         W

# %%
pred_fix.df[pred_fix.df.fixturedate=='2017-01-21']
# Out:
#     dummy   LeagueAlternateCode  seasonID fixturedate            HomeTeam  \
# 198     x    SKY BET LEAGUE TWO      2016  2017-01-21             Grimsby
# 212     x    SKY BET LEAGUE ONE      2016  2017-01-21             Walsall
# 211     x        PREMIER LEAGUE      2016  2017-01-21            Man City
# 210     x    SKY BET LEAGUE ONE      2016  2017-01-21  Milton Keynes Dons
# 209     x  SKY BET CHAMPIONSHIP      2016  2017-01-21             Norwich
# 208     x    SKY BET LEAGUE ONE      2016  2017-01-21            Charlton
# 207     x        PREMIER LEAGUE      2016  2017-01-21           West Brom
# 206     x    SKY BET LEAGUE ONE      2016  2017-01-21             Swindon
# 205     x    SKY BET LEAGUE TWO      2016  2017-01-21           Doncaster
# 204     x    SKY BET LEAGUE ONE      2016  2017-01-21          Shrewsbury
# 203     x        PREMIER LEAGUE      2016  2017-01-21         Bournemouth
# 202     x    SKY BET LEAGUE TWO      2016  2017-01-21          Cheltenham
# 201     x    SKY BET LEAGUE ONE      2016  2017-01-21            Southend
# 200     x  SKY BET CHAMPIONSHIP      2016  2017-01-21           Newcastle
# 199     x        PREMIER LEAGUE      2016  2017-01-21           Liverpool
# 213     x    SKY BET LEAGUE TWO      2016  2017-01-21       Leyton Orient
# 214     x  SKY BET CHAMPIONSHIP      2016  2017-01-21             Cardiff
# 226     x    SKY BET LEAGUE TWO      2016  2017-01-21              Barnet
# 216     x  SKY BET CHAMPIONSHIP      2016  2017-01-21            Barnsley
# 233     x        PREMIER LEAGUE      2016  2017-01-21       Middlesbrough
# 232     x    SKY BET LEAGUE ONE      2016  2017-01-21            Coventry
# 231     x    SKY BET LEAGUE ONE      2016  2017-01-21            Bradford
# 230     x    SKY BET LEAGUE TWO      2016  2017-01-21           Blackpool
# 229     x    SKY BET LEAGUE TWO      2016  2017-01-21           Cambridge
# 228     x    SKY BET LEAGUE ONE      2016  2017-01-21            Rochdale
# 227     x    SKY BET LEAGUE ONE      2016  2017-01-21        Chesterfield
# 215     x    SKY BET LEAGUE TWO      2016  2017-01-21          Accrington
# 225     x  SKY BET CHAMPIONSHIP      2016  2017-01-21           Blackburn
# 223     x  SKY BET CHAMPIONSHIP      2016  2017-01-21               Derby
# 222     x    SKY BET LEAGUE TWO      2016  2017-01-21          Hartlepool
# 221     x        PREMIER LEAGUE      2016  2017-01-21               Stoke
# 220     x    SKY BET LEAGUE TWO      2016  2017-01-21        Crawley Town
# 219     x    SKY BET LEAGUE TWO      2016  2017-01-21              Exeter
# 218     x    SKY BET LEAGUE ONE      2016  2017-01-21    Sheffield United
# 217     x    SKY BET LEAGUE TWO      2016  2017-01-21             Wycombe
# 224     x        PREMIER LEAGUE      2016  2017-01-21      Crystal Palace
#
#            AwayTeam  HomeTeamID  AwayTeamID  FTHG  FTAG    ...      \
# 198    Notts County          52          80     2     0    ...
# 212     Bristol Rvs         108          21     3     1    ...
# 211       Tottenham          68         106     2     2    ...
# 210     Northampton          73          77     5     3    ...
# 209          Wolves          78         115     3     1    ...
# 208      Scunthorpe          29          92     0     0    ...
# 207      Sunderland         111         102     2     0    ...
# 206       Peterboro         104          83     0     1    ...
# 205           Crewe          42          37     3     1    ...
# 204          Oldham          95          81     1     0    ...
# 203         Watford          15         109     2     2    ...
# 202        Plymouth          31          84     1     2    ...
# 201          Bolton          97          13     0     0    ...
# 200       Rotherham          75          91     4     0    ...
# 199         Swansea          65         103     2     3    ...
# 213       Morecambe          63          74     0     0    ...
# 214          Burton          27          24     1     0    ...
# 226  Newport County           7          76     0     0    ...
# 216           Leeds           8          61     3     2    ...
# 233        West Ham          71         112     1     3    ...
# 232  Fleetwood Town          35          47     0     1    ...
# 231        Millwall          16          72     1     1    ...
# 230          Yeovil          12         118     2     2    ...
# 229       Mansfield          26          70     1     3    ...
# 228          Oxford          90          82     0     4    ...
# 227   AFC Wimbledon          33           2     0     0    ...
# 215        Carlisle           1          28     1     1    ...
# 225      Birmingham          11          10     1     1    ...
# 223         Reading          41          89     3     2    ...
# 222       Stevenage          55          99     2     0    ...
# 221      Man United         101          69     1     1    ...
# 220      Portsmouth          36          86     0     0    ...
# 219      Colchester          46          34     3     0    ...
# 218      Gillingham          93          51     2     2    ...
# 217           Luton         117          66     1     1    ...
# 224         Everton          38          45     0     1    ...
#
#      FTAG_roll_avg_3  FTHG_roll_avg_diff_3 FTHG_roll_avg_4  FTAG_roll_avg_4  \
# 198         0.666667             -0.444444          3.2500             1.00
# 212         0.666667              1.444444          3.0000             1.00
# 211         2.666667             -0.666667          1.0625             2.25
# 210         0.333333              1.555556          2.1875             1.00
# 209         0.666667              1.444444          1.1250             0.50
# 208         1.000000              0.777778          0.9375             1.25
# 207         0.666667              0.888889          3.2500             0.50
# 206         1.333333             -0.888889          1.8750             1.00
# 205         0.333333              1.777778          1.7500             0.25
# 204         0.333333              0.222222          1.3125             0.75
# 203         0.000000              2.000000          1.6875             0.25
# 202         0.666667              0.777778          1.0000             0.50
# 201         1.000000              0.777778          0.9375             0.75
# 200         0.333333              1.888889          2.1250             0.50
# 199         1.000000              1.444444          2.3125             0.75
# 213         1.333333             -0.444444          1.2500             1.00
# 214         1.333333              0.555556          1.6250             1.00
# 226         1.000000             -0.111111          2.5000             1.00
# 216         1.000000              1.111111          1.4375             1.50
# 233         2.000000             -0.555556          1.3125             1.75
# 232         1.333333              0.000000          0.9375             1.25
# 231         0.666667              0.777778          1.6250             1.25
# 230         0.666667             -0.444444          1.6875             0.75
# 229         0.333333              1.555556          0.6875             0.75
# 228         1.666667              0.555556          1.2500             1.50
# 227         0.000000              0.444444          1.8750             0.00
# 215         1.666667             -0.666667          2.2500             1.50
# 225         0.666667              0.777778          2.2500             1.00
# 223         2.000000             -0.777778          2.0625             1.50
# 222         1.333333              0.222222          2.0000             1.00
# 221         2.000000             -0.111111          0.3750             1.75
# 220         1.333333              0.000000          1.5625             1.25
# 219         2.000000              1.000000          1.1250             1.50
# 218         0.666667              0.888889          1.3750             0.50
# 217         1.333333              0.111111          0.6875             1.00
# 224         2.000000             -1.555556          1.5625             1.50
#
#      FTHG_roll_avg_diff_4 FTHG_roll_avg_5  FTAG_roll_avg_5  \
# 198                2.2500            3.20              0.8
# 212                2.0000            3.00              0.8
# 211               -1.1875            1.28              2.0
# 210                1.1875            2.12              0.8
# 209                0.6250            1.08              0.6
# 208               -0.3125            1.44              1.4
# 207                2.7500            2.96              0.8
# 206                0.8750            1.44              1.0
# 205                1.5000            2.28              0.2
# 204                0.5625            1.48              0.6
# 203                1.4375            2.00              0.4
# 202                0.5000            0.76              1.0
# 201                0.1875            0.72              0.6
# 200                1.6250            2.08              0.4
# 199                1.5625            2.96              0.8
# 213                0.2500            0.96              1.0
# 214                0.6250            1.96              0.8
# 226                1.5000            2.88              1.4
# 216               -0.0625            1.56              1.4
# 233               -0.4375            1.24              1.8
# 232               -0.3125            1.20              1.2
# 231                0.3750            1.72              1.0
# 230                0.9375            1.52              1.0
# 229               -0.0625            1.72              0.6
# 228               -0.2500            1.20              1.2
# 227                1.8750            1.44              0.0
# 215                0.7500            1.96              1.6
# 225                1.2500            1.96              1.0
# 223                0.5625            2.76              1.8
# 222                1.0000            1.52              1.2
# 221               -1.3750            0.52              2.0
# 220                0.3125            1.20              1.6
# 219               -0.3750            0.84              1.8
# 218                0.8750            2.00              0.4
# 217               -0.3125            0.52              1.2
# 224                0.0625            1.44              1.2
#
#      FTHG_roll_avg_diff_5 PointsDiff  Predicted
# 198                  2.40          3          W
# 212                  2.20         -3          L
# 211                 -0.72          0          W
# 210                  1.32         -4          L
# 209                  0.48          5          W
# 208                  0.04         -1          L
# 207                  2.16         11          W
# 206                  0.44         -4          L
# 205                  2.08          4          W
# 204                  0.88         -3          L
# 203                  1.60          0          W
# 202                 -0.24        -17          L
# 201                  0.12         -3          L
# 200                  1.68         17          W
# 199                  2.16         23          W
# 213                 -0.04         -5          L
# 214                  1.16          5          W
# 226                  1.48          9          W
# 216                  0.16         -8          W
# 233                 -0.56         -3          L
# 232                  0.00         -5          L
# 231                  0.72         -1          L
# 230                  0.52         -2          W
# 229                  1.12         -6          L
# 228                  0.00         -1          L
# 227                  1.44        -10          L
# 215                  0.36        -15          L
# 225                  0.96         -3          L
# 223                  0.96          0          W
# 222                  0.32         -1          W
# 221                 -1.48         -7          L
# 220                 -0.40         -8          L
# 219                 -0.96         -1          W
# 218                  1.60          8          W
# 217                 -0.68         -5          D
# 224                  0.24        -11          L
#
# [36 rows x 30 columns]
